# %% [markdown]
# # Atividades mínimas: 65 pts

# %%
import numpy as np
import matplotlib.pyplot as plt
#Função para plotar curvas gaussianas com diferentes centros e larguras
def plot_gaussians():
    x = np.linspace(-10, 10, 400)
    centers = [-3, 0, 3]
    widths = [0.5, 1, 2]

    plt.figure(figsize=(8, 5))
    for c, w in zip(centers, widths):
        y = np.exp(-((x - c) ** 2) / (2 * w ** 2))  # Equação da função gaussiana
        plt.plot(x, y, label=f"center={c}, width={w}")

    plt.title("Função Gaussiana")
    plt.legend()
    plt.show()

def plot_sinc():
    x = np.linspace(-10, 10, 400)
    y = np.sinc(x / np.pi)  # Ajuste para a definição matemática usual

    plt.figure(figsize=(8, 5))
    plt.plot(x, y, label="sinc(x)")
    plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
    plt.title("Função Seno")
    plt.legend()
    plt.show()

def plot_exponential():
  #Função para plotar curvas exponenciais com diferentes coeficientes
    x = np.linspace(-2, 2, 400)
    a_values = [-10, -1, 2, 10]

    plt.figure(figsize=(8, 5))
    for a in a_values:
        y = np.exp(a * x) #Equação da função exponencial
        plt.plot(x, y, label=f"a={a}")

    plt.title("Função Exponencial")
    plt.legend()
    plt.show()
#Função da parabola
def plot_parabolas():
    cases = [
        (1, -3, 2),   # Discriminante positivo (duas raízes reais)
        (1, -2, 1),   # Discriminante zero (uma raiz real)
        (1, 1, 1)     # Discriminante negativo (raízes complexas)
    ]

    x = np.linspace(-5, 5, 400)
    plt.figure(figsize=(10, 6))

    for a, b, c in cases:
        y = a * x**2 + b * x + c #Equação da parabola
        discriminante = b**2 - 4*a*c

        if discriminante >= 0:
            r1 = (-b + np.sqrt(discriminante)) / (2 * a)
            r2 = (-b - np.sqrt(discriminante)) / (2 * a)
            plt.scatter([r1, r2], [0, 0], color='red', label=f"Raízes: {r1:.2f}, {r2:.2f}")

        plt.plot(x, y, label=f"a={a}, b={b}, c={c}")

    plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
    plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
    plt.title("Parábolas e suas raízes")
    plt.legend()
    plt.show()
#Chamando as funções para plotar os gráficos:
plot_gaussians()
plot_sinc()
plot_exponential()
plot_parabolas()

# %% [markdown]
# # Atividades intermediárias: 20 pts

# %%
import numpy as np

x = np.linspace(-10, 10, 1000)
y = np.sinc(x / np.pi)

# Salva os dados em arquivos separados
np.save('x_dados.npy', x)
np.save('y_dados.npy', y)

# arquivo: plotar_grafico.py
import numpy as np
import matplotlib.pyplot as plt

# Carrega os dados
x = np.load('x_dados.npy')
y = np.load('y_dados.npy')

# Plota o gráfico
plt.plot(x, y)
plt.title('Gráfico de sin(x)/x')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show()

# %% [markdown]
# # Atividades avançadas: 15 pts

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_deltoid():
    theta = np.linspace(0, 2 * np.pi, 400) #Cria 400 pontos igualmente espaçados
    x = 2 * np.cos(theta) + np.cos(2 * theta) #Fórmula para x da curva deltoide
    y = 2 * np.sin(theta) - np.sin(2 * theta)  #Fórmula para y da curva deltoide

    plt.figure(figsize=(6, 6)) #Define o tamanho do gráfico
    plt.plot(x, y, color='purple', label="Deltoid")  # Plota a curva
    plt.xlabel("x") # Nomeia o eixo x
    plt.ylabel("y") # Nomeia o eixo y
    plt.title("Curva Deltoid") #Adiciona um título
    plt.legend() #Adiciona legenda
    plt.grid() # adiciona grade
    plt.show() #exibe o gráfico

def plot_galileo_spiral():
    theta = np.linspace(0, 10 * np.pi, 400)
    r = theta**2
    x = r * np.cos(theta)
    y = r * np.sin(theta)

    plt.figure(figsize=(6, 6))
    plt.plot(x, y, color='purple', label="Espiral de Galileu")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.title("Espiral de Galileu")
    plt.legend()
    plt.grid()
    plt.show()

def plot_fey_function():
    theta = np.linspace(0, 24 * np.pi, 400)
    r = np.exp(np.cos(theta)) - 2 * np.cos(4 * theta) + np.sin(theta / 12)**5
    x = r * np.cos(theta)
    y = r * np.sin(theta)

    plt.figure(figsize=(6, 6))
    plt.plot(x, y, color='purple', label="Fey’s function: ")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.title("Fey’s function: ")
    plt.legend()
    plt.grid()
    plt.show()

# Chamando as funções para exibir os gráficos
plot_deltoid()
plot_galileo_spiral()
plot_fey_function()
